# %%
import numpy as np
import os
from PIL import Image
from pathlib import Path
import cv2
from IPython.display import display
import matplotlib.pyplot as plt
import scipy
import time
from sklearn.decomposition import PCA

# %%
features = []
img_paths = []

for feature_path in Path("./feature_vectors_resnet2/train").glob("*.npy"):
    fv = np.load(feature_path)
    features.append(fv)
    img_paths.append(Path("../webscraping/images_aggregate") / (feature_path.stem + ".jpg"))

# %%
features_test = []
test_imgs = []
i=0
for feature_path in Path("./feature_vectors_resnet2/test").glob("*.npy"):
    fv = np.load(feature_path)
    features_test.append(fv)
    test_imgs.append(Path("../webscraping/images_aggregate") / (feature_path.stem + ".jpg"))

# %%
from annoy import AnnoyIndex

# %%
feature_dim = len(features[0])
ann_index = AnnoyIndex(feature_dim, metric='angular')

# %%
for i in range(len(features)):
    ann_index.add_item(i, features[i])

ann_index.build(80)
# Out:
# True

# %%
ann_index.save('image_indexing')
# Out:
# True

# %%
ann_index = AnnoyIndex(len(features[0]),metric = 'angular')
ann_index.load('image_indexing')
# Out:
# True

# %%
num=10
N = 10

# %%
results = []
fig, ax = plt.subplots(num,N+1,figsize=(20, 20))
plt.tight_layout()

start = time.time()
for k in range(len(features_test)):
    
    
    if(k==num):
        break
    
    feature = np.array(features_test[k])
    ax[k,0].imshow((Image.open(test_imgs[k])))

    ax[k,0].axis('off')
    ax[k,0].set_title("Original",fontsize = 14, fontweight ='bold') 
    res = ann_index.get_nns_by_vector(feature, N ,include_distances=True)
    print("Result for Image: ",res)
    results.append(res)
    for j in range(len(res[0])):
        for i in range(len(img_paths)):

            if(i==res[0][j]):
                img = Image.open(img_paths[i])
                ax[k,j+1].imshow(img)
                ax[k,j+1].axis('off')
                ax[k,j+1].set_title("Similar image {} \n {:.5f}".format(j+1,res[1][j]),fontsize = 14, fontweight ='bold')
end= time.time()
# Out:
# Result for Image:  ([2227, 329, 672, 2726, 359, 3076, 993, 1990, 2148, 1699], [0.3407188951969147, 0.3574683964252472, 0.35765695571899414, 0.3624722957611084, 0.37328121066093445, 0.37631621956825256, 0.37663534283638, 0.3813979923725128, 0.3816073536872864, 0.3847479522228241])
# Result for Image:  ([2762, 689, 662, 1969, 767, 333, 2284, 1089, 884, 281], [0.5606819987297058, 0.5748282074928284, 0.5809525847434998, 0.5960533022880554, 0.5993391275405884, 0.6009953022003174, 0.609519362449646, 0.6117697954177856, 0.6160730123519897, 0.6210087537765503])
